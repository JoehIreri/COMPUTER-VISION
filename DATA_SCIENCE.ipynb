# %% [markdown]
# <a href="https://colab.research.google.com/github/JoehIreri/COMPUTER-VISION/blob/main/DATA_SCIENCE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
if 5 > 2:
    print("Five is greater than two")
# Out:
# Five is greater than two

# %%
#This program adds two numbers

num1 = 1.5
num2 = 6.3
#Add two numbers
sum = num1 + num2

#Display The Sum
print("The sum of {0} and {1} is {2}".format(num1,num2,sum))
# Out:
# The sum of 1.5 and 6.3 is 7.8

# %%
#This program adds two numbers entered by the user

a=int(input("enter first number : "))
b= int (input("enter second number : "))
#Add two number
sum= a + b
# Display the Sum
print("the sum of {0} and {1} is {2}".format(a,b,sum) )
# Out:
# enter first number : 20
# enter second number : 40
# the sum of 20 and 40 is 60

# %%
#Python Progarm to Calculate The Square Root

ict = 27
ans = ict**0.5
print ("The square root of %0.2f is %0.2f"%(ict ,ans))
# Out:
# The square root of 27.00 is 5.20

# %%
#Python Program to Calculate The Square Root
#import the math Module
import math
ict = 27

ans =math.sqrt(ict)
print("The Square Root of %0.2f is %0.2f"%(ict , ans))
# Out:
# The Square Root of 27.00 is 5.20

# %%
#Python Program to calculate the area of a triangle
# Takes inputs from the users
a = float(input('enter first side'))
b = float(input('enter second side'))
c = float(input('enter third number'))

#Calculate th semi perimeter
s = (a + b + c) / 2

#Calculate the area
area = (s*(s-a)*(s-b)*(s-c)) ** 0.5
print('The area of the triangle is %0.3f' %area)
# Out:
# enter first side20
# enter second side10
# enter third number5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-2b9927759aab> in <cell line: 12>()
#      10 #Calculate the area
#      11 area = (s*(s-a)*(s-b)*(s-c)) ** 0.5
# ---> 12 print('The area of the triangle is %0.3f' %area)
#
# TypeError: must be real number, not complex

# %%
# !pip install pandas

# %%
import matplotlib.pyplot as plt

labels= 'Java', 'Python', 'Ruby', 'C++'
sections= [26.2,26.9,30.6,16.2]
colors= ['b','y','r','g']
explode= [0,0.1,0,0]
plt.pie(sections,labels=labels,colors=colors,startangle=90,explode=(0,0.2,0,0),autopct='%1.2f%%')
plt.title('PROGRAMMING LANGUAGES USAGE')
plt.show()

# %%
import matplotlib.pyplot as plt

labels= 'A', 'B', 'C'
sections= [38.36,45.21,16.44]
colors= ['c','g','y']
explode= [0.2,0.1,0.01]
plt.pie(sections,labels=labels,colors=colors,startangle=90,explode=(0.2,0.1,0.01),autopct='%1.2f%%')
plt.title('GRADES FOR DATA SCIENCE')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["utilities","Health care","Energy","Consumer Staples","Communication Services"])
y=np.array([50,470,280,140,140])
colors=['b','m','g','r','b']
plt.barh(x,y, color=colors)
plt.plot()
plt.ylabel("Sector")
plt.xlabel("Frequency")
plt.title("DISRTIBUTION PER COURSE(SEP 2023 INTAKE -ZETECH UNIVESITY)")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["utilities","Health care","Energy","Consumer Staples","Communication Services"])
y=np.array([50,470,280,140,140])
colors=['b','m','g','r','b']
plt.bar(x,y, color=colors)
plt.plot()
plt.ylabel("Sector")
plt.xlabel("Frequency")
plt.title("DISRTIBUTION PER COURSE(SEP 2023 INTAKE -ZETECH UNIVESITY)")
plt.show()

# %%
import matplotlib.pyplot as plt
x1=[2,3,4,5,6]
y1=[0,10,20,30,40]

x2=["bus,car,bicycle,walking,train,motorcycle"]
y2=[0,10,20,30,40]

plt.bar(x1,y1,label="2022",color='c')
plt.bar(x2,y2,label="2023",color='m')
plt.plot()
plt.xlabel("Vehicle")
plt.ylabel("No. of Passangers")
plt.title("Commuter Travel in Nairobi(Kenya)")
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
vehicles = ["bus", "car", "bicycle", "walking", "train", "motorcycle"]
passengers_2022 = [24, 14, 12, 25, 20, 20]
passengers_2023 = [15, 48, 3, 5, 37, 2]

# Create bars
bar_width = 0.35
index = range(len(vehicles))

plt.bar(index, passengers_2022, bar_width, label='2022', color='cyan')
plt.bar([i + bar_width for i in index], passengers_2023, bar_width, label='2023', color='magenta')

# Set labels and title
plt.xlabel('Vehicles')
plt.ylabel('No. of Passengers')
plt.title('Commuter Travel in Nairobi (Kenya)')

# Set x-ticks and ticks labels
plt.xticks([i + bar_width / 2 for i in index], vehicles, rotation=45)

# Set y-ticks and ticks labels
plt.yticks([0, 10, 20, 30, 40])

# Add legend
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
counter = 100
print (counter)
# Out:
# 100

# %%
x ="Zara"
y = 10
z = 10.10

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
a = 10
b = 20
sum = a+b
print("sum",a,b)
# Out:
# sum 10 20

# %%
marks = 80
result =""
if marks < 30:
  result = "Failed"
elif marks > 75:
    result = "Passed with distiction"
else:
      result = "passed"

      print(result)

# %%
marks = 80
result =""
if marks < 30:
  result = "Failed"
elif marks > 75:
    result = "Passed with distiction"
else:
      result = "passed"

      print(result)
# Out:
#   File "<ipython-input-14-a97c33562419>", line 10
#     print(result
#                 ^
# SyntaxError: incomplete input

# %%
print("select an operation to perform:")
print("1. ADD")
print("2. SUBTRACT")
print("3. MULTIPLY")
print("4. DIVIDE")

operation = input()

if operation== 1:

    num1 = input("Enter first number: ")
    num2 = input("Enter second number: ")
    print("The sum is " + str(int(num1 + num2)))
elif operation== 2:
    num1 = input("Enter first number: ")
    num2 = input("Enter second number: ")
    print("The sum is " + str(int(num1 - num2)))
elif operation == 3:
    num1 = input("Enter first number: ")
    num2 = input("Enter second number: ")
    print("The sum is " + str(int(num1 * num2)))
elif operation== 4:
    num1 = input("Enter first number: ")
    num2 = input("Enter second number: ")
    print("The sum is " + str(int(num1 / num2)))
else:
    print("invalid Entry")
# Out:
# select an operation to perform:
# 1. ADD
# 2. SUBTRACT
# 3. MULTIPLY
# 4. DIVIDE
# 5
# invalid Entry

# %%
import pandas as pd
MallCustomers=pd.read_csv('/content/Mall_Customers.csv')
duplicate_rows = MallCustomers[MallCustomers.duplicated()]
print("Duplicate Rows:")
print(duplicate_rows)
# Out:
# Duplicate Rows:
# Empty DataFrame
# Columns: [CustomerID, Gender, Age, Annual Income (k$), Spending Score (1-100)]
# Index: []

# %%
import pandas as pd
MallCustomers= pd.read_csv('/content/Mall_Customers.csv')
AgeDuplicate = MallCustomers[MallCustomers['Age'].duplicated()]
print("Duplicated Age:")
print (AgeDuplicate)
# Out:
# Duplicated Age:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 7             8  Female   23                  18                      94
# 11           12  Female   35                  19                      99
# 15           16    Male   22                  20                      79
# 16           17  Female   35                  21                      35
# 17           18    Male   20                  21                      66
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [149 rows x 5 columns]

# %%
print("\nUnique Values in 'AGE' Column:")
print(MallCustomers['Age'].value_counts())
# Out:
# Unique Values in 'AGE' Column:
# 32    11
# 35     9
# 19     8
# 31     8
# 30     7
# 49     7
# 40     6
# 38     6
# 47     6
# 27     6
# 36     6
# 23     6
# 34     5
# 20     5
# 29     5
# 50     5
# 48     5
# 21     5
# 24     4
# 18     4
# 28     4
# 67     4
# 59     4
# 54     4
# 43     3
# 60     3
# 45     3
# 39     3
# 33     3
# 37     3
# 22     3
# 25     3
# 46     3
# 68     3
# 52     2
# 44     2
# 66     2
# 57     2
# 26     2
# 53     2
# 42     2
# 63     2
# 70     2
# 51     2
# 58     2
# 65     2
# 41     2
# 55     1
# 69     1
# 64     1
# 56     1
# Name: Age, dtype: int64

# %%
import pandas as pd
MallCustomers=pd.read_csv('/content/Mall_Customers.csv')
AgeDuplicateCount = MallCustomers['Age'].duplicated(keep=False).value_counts()
print("Counts of Duplicated students IDs:")
print(AgeDuplicateCount)
# Out:
# Counts of Duplicated students IDs:
# True     196
# False      4
# Name: Age, dtype: int64

# %%
import pandas as pd
MallCustomers=pd.read_csv('/content/Mall_Customers.csv')
null_values = MallCustomers.isnull().sum()
print("Null Values in the dataset")
print(null_values)
# Out:
# Null Values in the dataset
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
import pandas as pd
Joeh=pd.read_csv('/content/wainaina2.csv')
duplicate_rows = Joeh[Joeh.duplicated()]
print("Duplicate Rows:")
print(duplicate_rows)
# Out:
# Duplicate Rows:
# Empty DataFrame
# Columns: [StudentID , Age, Gender, TestScore, PassedExam]
# Index: []

# %%
import pandas as pd
Joeh= pd.read_csv('/content/wainaina2.csv')
AgeDuplicate = Joeh[Joeh['Age'].duplicated()]
print("Duplicated Age:")
print (AgeDuplicate)
# Out:
# Duplicated Age:
#    StudentID    Age  Gender  TestScore PassedExam
# 3           4  19.0  Female        NaN        Yes
# 4           5  20.0    Male       76.0         No
# 5           6  18.0    Male       90.0        Yes
# 6           7  19.0  Female       82.0        Yes
# 8           9  18.0    Male       79.0         No
# 9          10  19.0    Male       94.0        Yes

# %%
print("\nUnique Values in 'AGE' Column:")
print(Joeh['Age'].value_counts())
# Out:
# Unique Values in 'AGE' Column:
# 19.0    4
# 18.0    3
# 20.0    2
# Name: Age, dtype: int64

# %%
print("\nUnique Values in 'TestScore' Column:")
print(Joeh['TestScore'].value_counts())
# Out:
# Unique Values in 'TestScore' Column:
# 85.0    1
# 92.0    1
# 78.0    1
# 76.0    1
# 90.0    1
# 82.0    1
# 68.0    1
# 79.0    1
# 94.0    1
# Name: TestScore, dtype: int64

# %%
import pandas as pd
Joeh=pd.read_csv('/content/wainaina2.csv')
Joeh.head(10)
# Out:
#    StudentID    Age  Gender  TestScore PassedExam
# 0           1  18.0    Male       85.0        Yes
# 1           2  19.0  Female       92.0        Yes
# 2           3  20.0    Male       78.0         No
# 3           4  19.0  Female        NaN        Yes
# 4           5  20.0    Male       76.0         No
# 5           6  18.0    Male       90.0        Yes
# 6           7  19.0  Female       82.0        Yes
# 7           8   NaN  Female       68.0         No
# 8           9  18.0    Male       79.0         No
# 9          10  19.0    Male       94.0        Yes

# %%
import pandas as pd
Joeh= pd.read_csv('/content/wainaina2.csv')
FilledData = Joeh.fillna(0)
print("Dataset with missing values replaced:")
print(FilledData)
# Out:
# Dataset with missing values replaced:
#    StudentID    Age  Gender  TestScore PassedExam
# 0           1  18.0    Male       85.0        Yes
# 1           2  19.0  Female       92.0        Yes
# 2           3  20.0    Male       78.0         No
# 3           4  19.0  Female        0.0        Yes
# 4           5  20.0    Male       76.0         No
# 5           6  18.0    Male       90.0        Yes
# 6           7  19.0  Female       82.0        Yes
# 7           8   0.0  Female       68.0         No
# 8           9  18.0    Male       79.0         No
# 9          10  19.0    Male       94.0        Yes

# %%
import pandas as pd
wainaina=pd.read_csv('/content/wainaina.csv')
print("\nFirst 10 Rows of the DataFrame:")
print(wainaina.head(10))
# Display summary statistics for numeric columns
print("\nSummary Statistics:")
print(wainaina.describe())
# Display data types and non-null counts
print("\nData Types and Non-Null Counts:")
print(wainaina.info())
# Count unique values in the 'Passed Exam' column
print("\nUnique Values in 'Passed Exam' Column:")
print(wainaina['PassedExam'].value_counts())
# Count unique values in the 'Gender' column
print("\nUnique Values in 'Gender' Column:")
print(wainaina['Gender'].value_counts())

# %%
import pandas as pd
import matplotlib.pyplot as plt
mydata=pd.read_csv('/content/machine_learning/MyDrive/Share slim (1).csv')
mydata.head(5)
#Visualization Code:
country_data = mydata["name"]
medal_data = mydata["gold"]
colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#8c564b"]
explode = (0.1, 0, 0, 0, 0)
plt.pie(medal_data, labels=country_data, explode=explode, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Gold medal achievements of five most successful\n"+"countries in 2023 Summer Olympics")
plt.show()
print(mydata)
# Out:
#        name  gold
# 0       USA    46
# 1   Britain    27
# 2     China    26
# 3   Russian    19
# 4  Germany     27

# %%
mydata = pd.read_csv('/content/machine_learning/MyDrive/Share slim (1).csv')
country_data = mydata["name"]
medal_data = mydata["gold"]
plt.bar(country_data,medal_data)
plt.plot()
plt.xlabel("country_data")
plt.ylabel("medal_data")
plt.title("Gold medal achievements of five most successful\n"+"countries in 2023 Summer Olympics")
plt.show()

# %%
from google.colab import drive
drive.mount("/content/machine_learning")
# Out:
# Mounted at /content/machine_learning

# %% [markdown]
# # New Section

# %%
from google.colab import drive
drive.mount('/content/drive')
